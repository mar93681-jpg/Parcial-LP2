# %% [markdown]
# <table>
#   <tr>
#     <td style="padding-right: 20px;">
#       <img src="https://upload.wikimedia.org/wikipedia/commons/a/a9/Unalm_logo.png" width="115" />
#     </td>
#     <td style="vertical-align: top; font-size: 20px; line-height: 1.0;">
#       <strong>Universidad Nacional Agraria La Molina</strong><br><br>
#       Facultad de Economía y Planificación<br><br>
#       Departamento de Estadística e Informática
#     </td>
#   </tr>
# </table>
#
# # Lenguaje de Programación II
#
# **Docente:** Ana Cecilia Vargas Paredes
# 📧 *anavargas@lamolina.edu.pe*
# 🕒 *Horario de atención:* Martes y jueves, 11:00 – 12:00 h
# 🏫 *Oficina:* N.º 13, Facultad de Economía y Planificación
#
# ---
#
# ## 🧮 Evaluación Grupal 1 (25%)
#
# **Tema:**
# > Desarrollo de una librería en Python que realice estadísticas básicas utilizando Programación Orientada a Objetos (POO).
# > Incluye clases, herencia y polimorfismo para el análisis de datos cuantitativos y cualitativos.
#
# **Fecha de entrega:** 28 de octubre (23:55 h)
# **Fecha de presentación:** 30 de octubre
#
# ---
#
# ## 👥 Integrantes del grupo
#
# | Integrante   | Aporte   |
# |---------------|----------|
# | Jean Franco   | Tarea 1: Arquitectura y Clase Base (25%)  |
# | Hilary        | Tarea 2: Estadísticas Cuantitativas (25%)  |
# | Mario         | Tarea 3: Estadísticas Cualitativas (25%)  |
# | Piero         | Tarea 4: Integración, Polimorfismo y Pruebas (25%)  |
#
# ---
#
# ## 📋 Descripción del caso
#
# > **Objetivo:**
# > Desarrollar un paquete o librería en Python que realice **estadísticas básicas** (resúmenes) para datos cuantitativos y cualitativos utilizando principios de **Programación Orientada a Objetos (POO)**.
#
# **Estadísticas consideradas:**
# - **Cuantitativas:** media, mediana, desviación estándar, percentiles, etc.
# - **Cualitativas:** moda(s) y tabla de frecuencia.
#
# ---
#
# ## 🧩 Estructura del proyecto
#
# El proyecto está dividido en tres módulos:
#
# ```text
# 📦 Proyecto_Estadistico/
#  ┣ 📜 estadistica_cuantitativa.py
#  ┣ 📜 estadistica_cualitativa.py
#  ┣ 📜 simular_datos.py
#  ┗ 📜 datos_simulados.csv
#  ┗ 📜 main.py

# %% [markdown]
# ## 🧠 Carga de datos
#
# El archivo `datos_simulados.csv` contiene **8 columnas**:
#
# | **Tipo de Variable** | **Variables** |
# |------------------------|------------------------------------------------------------|
# | Cuantitativas | Edad, Ingreso_mensual_miles, Horas_trabajadas_por_semana, Gasto_mensual_miles |
# | Cualitativas | Color_favorito, Ocupacion, Genero, Estado_civil |

# %%
import pandas as pd

# Cargar el dataset
df = pd.read_csv('datos_simulados.csv')
df.head()
# Out:
#    ID  Edad  Horas_trabajadas_por_semana  Ingreso_mensual_miles  \
# 0   1    27                           59                   4.78
# 1   2    24                           39                   3.59
# 2   3    52                           27                   7.40
# 3   4    29                           47                   4.95
# 4   5    63                           36                   9.56
#
#    Gasto_mensual_miles Color_favorito    Ocupacion Estado_civil     Genero
# 0                 3.89          negro  programador       casado   femenino
# 1                 3.16           rojo  programador   divorciado  masculino
# 2                 6.49         morado   estudiante      soltero   femenino
# 3                 4.27           azul     vendedor   divorciado   femenino
# 4                 9.48       amarillo    ingeniero        viudo   femenino

# %% [markdown]
# ## ⚙️ Ejecución del programa principal
#
# A continuación, ejecutamos el archivo **main.py**, que:
# 1. Carga los datos del CSV.
# 2. Crea objetos de clases para cada tipo de variable.
# 3. Aplica **polimorfismo** para mostrar los resúmenes estadísticos.

# %%
# !python main.py
# Out:
# CLASE CUANTITATIVA
#
# Probando la clase:
# Creado exitosamente uu
# ==================================================
#      RESUMEN ESTADÍSTICAS CUANTITATIVAS
# ==================================================
# Cantidad: 13
# Mínimo: 12.00
# Máximo: 90.00
# Rango: 78.00
#
# --- TENDENCIA CENTRAL ---
# Media: 51.85
# Mediana: 45.00
# Moda: [45]
#
# --- DISPERSIÓN ---
# Varianza: 592.90
# Desviación: 24.35
# Coef. variación: 46.96%
#
# --- CUARTILES ---
# Q1: 34.00, Q2: 45.00, Q3: 67.00
# IQR: 33.00
# ==================================================
# ----- RESUMEN DE DATOS -----
# Cantidad de datos: 5
# Valor mínimo: 10
# Valor máximo: 50
# Promedio: 30.00
# ----------------------------
#
#  Resumen (EstadisticaCuantitativa)
# ==================================================
#      RESUMEN ESTADÍSTICAS CUANTITATIVAS
# ==================================================
# Cantidad: 200
# Mínimo: 18.00
# Máximo: 65.00
# Rango: 47.00
#
# --- TENDENCIA CENTRAL ---
# Media: 40.28
# Mediana: 38.00
# Moda: [20]
#
# --- DISPERSIÓN ---
# Varianza: 190.79
# Desviación: 13.81
# Coef. variación: 34.29%
#
# --- CUARTILES ---
# Q1: 28.00, Q2: 38.00, Q3: 52.00
# IQR: 24.00
# ==================================================
#
#  Resumen (EstadisticaCuantitativa)
# ==================================================
#      RESUMEN ESTADÍSTICAS CUANTITATIVAS
# ==================================================
# Cantidad: 200
# Mínimo: 1.55
# Máximo: 9.93
# Rango: 8.38
#
# --- TENDENCIA CENTRAL ---
# Media: 5.60
# Mediana: 5.56
# Moda: [2.57]
#
# --- DISPERSIÓN ---
# Varianza: 5.17
# Desviación: 2.27
# Coef. variación: 40.60%
#
# --- CUARTILES ---
# Q1: 3.77, Q2: 5.56, Q3: 7.35
# IQR: 3.58
# ==================================================
#
#  Resumen (EstadisticaCuantitativa)
# ==================================================
#      RESUMEN ESTADÍSTICAS CUANTITATIVAS
# ==================================================
# Cantidad: 200
# Mínimo: 20.00
# Máximo: 60.00
# Rango: 40.00
#
# --- TENDENCIA CENTRAL ---
# Media: 40.65
# Mediana: 40.00
# Moda: [60.0]
#
# --- DISPERSIÓN ---
# Varianza: 139.98
# Desviación: 11.83
# Coef. variación: 29.11%
#
# --- CUARTILES ---
# Q1: 31.00, Q2: 40.00, Q3: 51.00
# IQR: 20.00
# ==================================================
#
#  Resumen (EstadisticaCuantitativa)
# ==================================================
#      RESUMEN ESTADÍSTICAS CUANTITATIVAS
# ==================================================
# Cantidad: 200
# Mínimo: 1.27
# Máximo: 9.66
# Rango: 8.39
#
# --- TENDENCIA CENTRAL ---
# Media: 5.07
# Mediana: 5.05
# Moda: [1.85, 5.27, 4.86]
#
# --- DISPERSIÓN ---
# Varianza: 4.37
# Desviación: 2.09
# Coef. variación: 41.23%
#
# --- CUARTILES ---
# Q1: 3.37, Q2: 5.05, Q3: 6.65
# IQR: 3.29
# ==================================================
#
#  Resumen (EstadisticaCualitativa)
# ----- RESUMEN DE DATOS (CUALITATIVOS) -----
# Cantidad de datos: 200
# Moda(s): morado
#
# --- Tabla de Frecuencias ---
#   - morado: 36
#   - rojo: 33
#   - verde: 29
#   - azul: 28
#   - blanco: 27
#   - negro: 24
#   - amarillo: 23
# -----------------------------------------------------
#
#  Resumen (EstadisticaCualitativa)
# ----- RESUMEN DE DATOS (CUALITATIVOS) -----
# Cantidad de datos: 200
# Moda(s): ingeniero
#
# --- Tabla de Frecuencias ---
#   - ingeniero: 40
#   - vendedor: 35
#   - estudiante: 34
#   - programador: 32
#   - docente: 31
#   - médico: 28
# -----------------------------------------------------
#
#  Resumen (EstadisticaCualitativa)
# ----- RESUMEN DE DATOS (CUALITATIVOS) -----
# Cantidad de datos: 200
# Moda(s): femenino
#
# --- Tabla de Frecuencias ---
#   - femenino: 78
#   - masculino: 66
#   - otro: 56
# -----------------------------------------------------
#
#  Resumen (EstadisticaCualitativa)
# ----- RESUMEN DE DATOS (CUALITATIVOS) -----
# Cantidad de datos: 200
# Moda(s): casado, soltero
#
# --- Tabla de Frecuencias ---
#   - casado: 57
#   - soltero: 57
#   - viudo: 44
#   - divorciado: 42
# -----------------------------------------------------

# %% [markdown]
# ## 📊 Resultados esperados
#
# El programa imprime resúmenes para las siguientes variables:
#
# **Cuantitativas:**
# - Edad
# - Ingreso mensual (miles)
# - Horas trabajadas por semana
# - Gasto mensual (miles)
#
# **Cualitativas:**
# - Color favorito
# - Ocupación
# - Género
# - Estado civil

# %% [markdown]
# ## 💡 Principios de POO aplicados
#
# | Concepto | Aplicación |
# |-----------|-------------|
# | **Encapsulamiento** | Cada clase administra sus propios métodos y atributos. |
# | **Herencia** | Las clases específicas pueden compartir una base común. |
# | **Polimorfismo** | La función `mostrar_resumen()` actúa sobre distintos tipos de objetos. |
# | **Modularidad** | El código se organiza en archivos reutilizables. |

# %% [markdown]
# ## 🧾 Conclusión
#
# Este trabajo demuestra cómo la **Programación Orientada a Objetos (POO)** permite crear una librería clara, reutilizable y bien estructurada para análisis estadístico.
#
# El uso del **polimorfismo** simplifica el proceso de obtener resúmenes para distintos tipos de datos, mostrando cómo un mismo método puede comportarse de manera diferente según el objeto.
#
# ---
#
# ✅ **Resultado final:**
# Un sistema modular y escalable para análisis estadístico básico con Python y POO.
